# %% [markdown]
# # Data input/Output

# %% [markdown]
# ## Load raw data
#
# Data files are laded form `data/raw` on a stack. RGB channels values are average to get intesity value.

# %%
from research_ct.io.volume_loader import Load_Slice_Stack

Volume  = Load_Slice_Stack(
Folder="/home/mia/Mitacs/research_ct/data/raw/"
)
# Out:
# [Load_Slice_Stack] 201 slices from /home/mia/Mitacs/research_ct/data/raw
# [Load_Slice_Stack] Volume: (201, 1828, 2165), range [0.0, 60735.0]

# %% [markdown]
# ## Save volume
#
# Loades volume is saved as stack using *slice* nmae and numeration. It is stored in test folder.

# %%
from research_ct.io.volume_loader import Save_Volume_As_Stack
Save_Volume_As_Stack(
    Volume=Volume,
    Folder="/home/mia/Mitacs/research_ct/data/output/first_test/"
)
# Out:
# [Save_Volume_As_Stack] 201 slices → /home/mia/Mitacs/research_ct/data/output/first_test

# %% [markdown]
# ## Save volume data
#
# Once segemntation and analysis processes takes places, data can be save using _npz_ format

# %%
from research_ct.io.volume_saver import Save_As_Numpy, Load_From_Numpy

Save_As_Numpy(
    Volume=Volume, File_Path="/home/mia/Mitacs/research_ct/data/output/first_test/mi_volumen"
)
# Out:
# [Save_As_Numpy] Saved → /home/mia/Mitacs/research_ct/data/output/first_test/mi_volumen

# %% [markdown]
# _npz_ files can be loaded to

# %%
Volume = Load_From_Numpy(
    File_Path="/home/mia/Mitacs/research_ct/data/output/first_test/mi_volumen.npz"
)
print(f"Volume shape: {Volume.shape}, dtype: {Volume.dtype}")
# Out:
# [Load_From_Numpy] Loaded: (201, 1828, 2165)
# Volume shape: (201, 1828, 2165), dtype: float64
